# %% [markdown]
# **Settings**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/5.2+correlazione
# Out:
# /gdrive/My Drive/5.2+correlazione

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# Data Loading in a *dataframe*

# %%
dataset = pd.read_csv('Training.csv')
print(dataset.shape)
dataset.head()
# Out:
# (68528, 7)
#    Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# 0     7.97698       4.33494  ...          51.681460    3.65434
# 1     8.07824       4.44616  ...          51.563598    3.47672
# 2     8.02844       4.22372  ...          50.863080    3.47672
# 3     8.02844       4.22372  ...          45.841581    3.47672
# 4     7.87572       4.44616  ...          47.126421    3.47672
#
# [5 rows x 7 columns]

# %%
#Let's check the correlation 
dataset.corr()
#Crunchiness and Hype root are 99% correlated
#Wonder level and Loudness on impact are 93% correlated
# Out:
#                     Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# Sponginess            1.000000      0.253002  ...           0.127885   0.183141
# Wonder level          0.253002      1.000000  ...           0.237021   0.074392
# Crunchiness           0.297509      0.119078  ...           0.061539   0.987209
# Loudness on impact    0.121744      0.930254  ...           0.229336   0.048806
# Meme creativity       0.331200      0.367438  ...           0.078168  -0.040596
# Soap slipperiness     0.127885      0.237021  ...           1.000000   0.050996
# Hype root             0.183141      0.074392  ...           0.050996   1.000000
#
# [7 rows x 7 columns]

# %% [markdown]
# *Training - Test* (0.90/0.1) **split** + **Normalization** (MinMax scaler)

# %%
#Split
dataset_len = len(dataset)
print(dataset_len)
split=0.1
test_size=int(dataset_len*split) # validation set size
print(test_size)
X_train_raw = dataset.iloc[:-test_size]
X_test_raw = dataset.iloc[-test_size:]
print(X_train_raw.shape, X_test_raw.shape)

X_min = X_train_raw.min()
X_max = X_train_raw.max()
print("X_max = ", X_max)
print("X_min = ", X_min)

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_test_raw = (X_test_raw-X_min)/(X_max-X_min)


# Plot of Training and Validation split with normalized data
plt.figure(figsize=(17,5))
plt.plot(X_train_raw.Crunchiness, label='Train (Crunchiness)')
plt.plot(X_test_raw.Crunchiness, label='Test (Crunchiness)')
plt.title('Train-Test Split')
plt.legend()
plt.show()
# Out:
# 68528
# 6852
# (61676, 7) (6852, 7)
# X_max =  Sponginess            15.106680
# Wonder level          18.122899
# Crunchiness           41.138801
# Loudness on impact    14.035980
# Meme creativity        6.056360
# Soap slipperiness     77.371620
# Hype root             31.024420
# dtype: float64
# X_min =  Sponginess            -0.972080
# Wonder level          -8.450380
# Crunchiness          -34.802881
# Loudness on impact    -9.028060
# Meme creativity       -1.275860
# Soap slipperiness     -6.006860
# Hype root            -38.816760
# dtype: float64

# %% [markdown]
# Parameters for Time Series forecasting with an AutoRegressive model

# %%
window = 315 
stride = 21  # chosen such that window/stride has no residual in the division
target_labels = dataset.columns    # multivariate forecasting
telescope = 9    # How much far away I want to look in the future

# %%
future = dataset[-window:] # FUTURE is the last window of the dataset
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 315, 7)

# %% [markdown]
# Build the sequences (using previous parameters), necessary for training the network

# %%
def build_sequences(df, target_labels=dataset.columns, window=window, stride=stride, telescope=telescope):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
X_test, y_test = build_sequences(X_test_raw, target_labels, window, stride, telescope)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2925, 315, 7), (2925, 9, 7), (315, 315, 7), (315, 9, 7))

# %% [markdown]
# >DATA CLEANING

# %%
# Correlation: remove crunchiness and wonder level from training set, redundant
X_train = np.delete(X_train,[1,2],2) 
print(X_train.shape,y_train.shape)
# Out:
# (2925, 315, 5) (2925, 9, 7)

# %%
# Model metadata
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 64
epochs = 300

# %% [markdown]
# Neural network: definition, construction and training

# %%
# model (inspired by one done in Lab classes)

def build_CONV_LSTM_model(input_shape, output_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    convlstm = tfkl.Bidirectional(tfkl.LSTM(64, return_sequences=True))(input_layer)
    convlstm = tfkl.Conv1D(128, 3, padding='same', activation='relu')(convlstm)
    convlstm = tfkl.MaxPool1D()(convlstm)
    convlstm = tfkl.Bidirectional(tfkl.LSTM(128, return_sequences=True))(convlstm)
    convlstm = tfkl.Conv1D(256, 3, padding='same', activation='relu')(convlstm)
    convlstm = tfkl.GlobalAveragePooling1D()(convlstm)
    convlstm = tfkl.Dropout(.5)(convlstm)

    

    dense = tfkl.Dense(output_shape[-1]*output_shape[-2], activation='relu')(convlstm)
    output_layer = tfkl.Reshape((output_shape[-2],output_shape[-1]))(dense)
    output_layer = tfkl.Conv1D(output_shape[-1], 1, padding='same')(output_layer)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae']) # idea: create models using different losses!

    # Return the model
    return model

# %%
model = build_CONV_LSTM_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 315, 5)]          0
#
#  bidirectional (Bidirectiona  (None, 315, 128)         35840
#  l)
#
#  conv1d (Conv1D)             (None, 315, 128)          49280
#
#  max_pooling1d (MaxPooling1D  (None, 157, 128)         0
#  )
#
#  bidirectional_1 (Bidirectio  (None, 157, 256)         263168
#  nal)
#
#  conv1d_1 (Conv1D)           (None, 157, 256)          196864
#
#  global_average_pooling1d (G  (None, 256)              0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 63)                16191
#
#  reshape (Reshape)           (None, 9, 7)              0
#
#  conv1d_2 (Conv1D)           (None, 9, 7)              56
#
# =================================================================
# Total params: 561,399
# Trainable params: 561,399
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=25, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/300
# 42/42 [==============================] - 27s 270ms/step - loss: 0.1054 - mae: 0.2591 - val_loss: 0.0377 - val_mae: 0.1550 - lr: 0.0010
# Epoch 2/300
# 42/42 [==============================] - 9s 214ms/step - loss: 0.0369 - mae: 0.1511 - val_loss: 0.0214 - val_mae: 0.1129 - lr: 0.0010
# Epoch 3/300
# 42/42 [==============================] - 9s 214ms/step - loss: 0.0249 - mae: 0.1228 - val_loss: 0.0193 - val_mae: 0.1040 - lr: 0.0010
# Epoch 4/300
# 42/42 [==============================] - 9s 214ms/step - loss: 0.0213 - mae: 0.1128 - val_loss: 0.0195 - val_mae: 0.1056 - lr: 0.0010
# Epoch 5/300
# 42/42 [==============================] - 9s 214ms/step - loss: 0.0200 - mae: 0.1091 - val_loss: 0.0185 - val_mae: 0.0998 - lr: 0.0010
# Epoch 6/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0188 - mae: 0.1056 - val_loss: 0.0199 - val_mae: 0.1064 - lr: 0.0010
# Epoch 7/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0180 - mae: 0.1033 - val_loss: 0.0180 - val_mae: 0.1002 - lr: 0.0010
# Epoch 8/300
# 42/42 [==============================] - 9s 213ms/step - loss: 0.0173 - mae: 0.1009 - val_loss: 0.0171 - val_mae: 0.0962 - lr: 0.0010
# Epoch 9/300
# 42/42 [==============================] - 9s 213ms/step - loss: 0.0165 - mae: 0.0981 - val_loss: 0.0172 - val_mae: 0.0975 - lr: 0.0010
# Epoch 10/300
# 42/42 [==============================] - 9s 213ms/step - loss: 0.0161 - mae: 0.0965 - val_loss: 0.0180 - val_mae: 0.0997 - lr: 0.0010
# Epoch 11/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0159 - mae: 0.0962 - val_loss: 0.0169 - val_mae: 0.0948 - lr: 0.0010
# Epoch 12/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0153 - mae: 0.0943 - val_loss: 0.0171 - val_mae: 0.0938 - lr: 0.0010
# Epoch 13/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0150 - mae: 0.0928 - val_loss: 0.0172 - val_mae: 0.0974 - lr: 0.0010
# Epoch 14/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0147 - mae: 0.0920 - val_loss: 0.0161 - val_mae: 0.0885 - lr: 0.0010
# Epoch 15/300
# 42/42 [==============================] - 9s 213ms/step - loss: 0.0145 - mae: 0.0909 - val_loss: 0.0163 - val_mae: 0.0920 - lr: 0.0010
# Epoch 16/300
# 42/42 [==============================] - 9s 213ms/step - loss: 0.0143 - mae: 0.0900 - val_loss: 0.0157 - val_mae: 0.0879 - lr: 0.0010
# Epoch 17/300
# 42/42 [==============================] - 9s 213ms/step - loss: 0.0142 - mae: 0.0895 - val_loss: 0.0157 - val_mae: 0.0864 - lr: 0.0010
# Epoch 18/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0137 - mae: 0.0878 - val_loss: 0.0158 - val_mae: 0.0904 - lr: 0.0010
# Epoch 19/300
# 42/42 [==============================] - 9s 213ms/step - loss: 0.0138 - mae: 0.0882 - val_loss: 0.0153 - val_mae: 0.0885 - lr: 0.0010
# Epoch 20/300
# 42/42 [==============================] - 9s 213ms/step - loss: 0.0133 - mae: 0.0861 - val_loss: 0.0150 - val_mae: 0.0840 - lr: 0.0010
# Epoch 21/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0132 - mae: 0.0857 - val_loss: 0.0160 - val_mae: 0.0857 - lr: 0.0010
# Epoch 22/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0129 - mae: 0.0851 - val_loss: 0.0150 - val_mae: 0.0856 - lr: 0.0010
# Epoch 23/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0127 - mae: 0.0840 - val_loss: 0.0148 - val_mae: 0.0829 - lr: 0.0010
# Epoch 24/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0123 - mae: 0.0826 - val_loss: 0.0143 - val_mae: 0.0844 - lr: 0.0010
# Epoch 25/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0117 - mae: 0.0810 - val_loss: 0.0112 - val_mae: 0.0745 - lr: 0.0010
# Epoch 26/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0105 - mae: 0.0779 - val_loss: 0.0111 - val_mae: 0.0748 - lr: 0.0010
# Epoch 27/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0099 - mae: 0.0750 - val_loss: 0.0114 - val_mae: 0.0736 - lr: 0.0010
# Epoch 28/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0099 - mae: 0.0750 - val_loss: 0.0127 - val_mae: 0.0770 - lr: 0.0010
# Epoch 29/300
# 42/42 [==============================] - 9s 210ms/step - loss: 0.0095 - mae: 0.0735 - val_loss: 0.0104 - val_mae: 0.0713 - lr: 0.0010
# Epoch 30/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0090 - mae: 0.0710 - val_loss: 0.0097 - val_mae: 0.0712 - lr: 0.0010
# Epoch 31/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0091 - mae: 0.0715 - val_loss: 0.0096 - val_mae: 0.0713 - lr: 0.0010
# Epoch 32/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0088 - mae: 0.0702 - val_loss: 0.0109 - val_mae: 0.0718 - lr: 0.0010
# Epoch 33/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0088 - mae: 0.0701 - val_loss: 0.0102 - val_mae: 0.0685 - lr: 0.0010
# Epoch 34/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0086 - mae: 0.0693 - val_loss: 0.0099 - val_mae: 0.0733 - lr: 0.0010
# Epoch 35/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0085 - mae: 0.0685 - val_loss: 0.0100 - val_mae: 0.0679 - lr: 0.0010
# Epoch 36/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0085 - mae: 0.0683 - val_loss: 0.0102 - val_mae: 0.0715 - lr: 0.0010
# Epoch 37/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0079 - mae: 0.0659 - val_loss: 0.0091 - val_mae: 0.0687 - lr: 5.0000e-04
# Epoch 38/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0080 - mae: 0.0663 - val_loss: 0.0088 - val_mae: 0.0663 - lr: 5.0000e-04
# Epoch 39/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0078 - mae: 0.0653 - val_loss: 0.0094 - val_mae: 0.0683 - lr: 5.0000e-04
# Epoch 40/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0077 - mae: 0.0651 - val_loss: 0.0089 - val_mae: 0.0676 - lr: 5.0000e-04
# Epoch 41/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0075 - mae: 0.0643 - val_loss: 0.0088 - val_mae: 0.0690 - lr: 5.0000e-04
# Epoch 42/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0072 - mae: 0.0627 - val_loss: 0.0079 - val_mae: 0.0637 - lr: 5.0000e-04
# Epoch 43/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0077 - mae: 0.0651 - val_loss: 0.0084 - val_mae: 0.0658 - lr: 5.0000e-04
# Epoch 44/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0074 - mae: 0.0641 - val_loss: 0.0079 - val_mae: 0.0656 - lr: 5.0000e-04
# Epoch 45/300
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0072 - mae: 0.0631 - val_loss: 0.0079 - val_mae: 0.0646 - lr: 5.0000e-04
# Epoch 46/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0070 - mae: 0.0617 - val_loss: 0.0073 - val_mae: 0.0632 - lr: 5.0000e-04
# Epoch 47/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0068 - mae: 0.0615 - val_loss: 0.0074 - val_mae: 0.0628 - lr: 5.0000e-04
# Epoch 48/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0066 - mae: 0.0602 - val_loss: 0.0069 - val_mae: 0.0605 - lr: 5.0000e-04
# Epoch 49/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0071 - val_mae: 0.0619 - lr: 5.0000e-04
# Epoch 50/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0065 - mae: 0.0599 - val_loss: 0.0070 - val_mae: 0.0622 - lr: 5.0000e-04
# Epoch 51/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0062 - mae: 0.0584 - val_loss: 0.0073 - val_mae: 0.0646 - lr: 5.0000e-04
# Epoch 52/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0062 - mae: 0.0583 - val_loss: 0.0066 - val_mae: 0.0600 - lr: 5.0000e-04
# Epoch 53/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0060 - mae: 0.0569 - val_loss: 0.0060 - val_mae: 0.0553 - lr: 5.0000e-04
# Epoch 54/300
# 42/42 [==============================] - 9s 211ms/step - loss: 0.0058 - mae: 0.0557 - val_loss: 0.0060 - val_mae: 0.0568 - lr: 5.0000e-04
# Epoch 55/300
# 42/42 [==============================] - 9s 210ms/step - loss: 0.0058 - mae: 0.0562 - val_loss: 0.0058 - val_mae: 0.0550 - lr: 5.0000e-04
# Epoch 56/300
# 42/42 [==============================] - 9s 210ms/step - loss: 0.0056 - mae: 0.0548 - val_loss: 0.0060 - val_mae: 0.0565 - lr: 5.0000e-04
# Epoch 57/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0055 - mae: 0.0546 - val_loss: 0.0059 - val_mae: 0.0562 - lr: 5.0000e-04
# Epoch 58/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0054 - mae: 0.0541 - val_loss: 0.0053 - val_mae: 0.0515 - lr: 5.0000e-04
# Epoch 59/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0055 - mae: 0.0545 - val_loss: 0.0052 - val_mae: 0.0508 - lr: 5.0000e-04
# Epoch 60/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0053 - mae: 0.0531 - val_loss: 0.0055 - val_mae: 0.0540 - lr: 5.0000e-04
# Epoch 61/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0053 - mae: 0.0528 - val_loss: 0.0053 - val_mae: 0.0520 - lr: 5.0000e-04
# Epoch 62/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0050 - mae: 0.0516 - val_loss: 0.0053 - val_mae: 0.0516 - lr: 5.0000e-04
# Epoch 63/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0051 - mae: 0.0518 - val_loss: 0.0052 - val_mae: 0.0521 - lr: 5.0000e-04
# Epoch 64/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0050 - mae: 0.0511 - val_loss: 0.0049 - val_mae: 0.0492 - lr: 2.5000e-04
# Epoch 65/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0049 - mae: 0.0506 - val_loss: 0.0050 - val_mae: 0.0501 - lr: 2.5000e-04
# Epoch 66/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0049 - mae: 0.0503 - val_loss: 0.0050 - val_mae: 0.0518 - lr: 2.5000e-04
# Epoch 67/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0048 - mae: 0.0501 - val_loss: 0.0048 - val_mae: 0.0497 - lr: 2.5000e-04
# Epoch 68/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0048 - mae: 0.0502 - val_loss: 0.0050 - val_mae: 0.0512 - lr: 2.5000e-04
# Epoch 69/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0047 - mae: 0.0497 - val_loss: 0.0048 - val_mae: 0.0490 - lr: 2.5000e-04
# Epoch 70/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0047 - mae: 0.0498 - val_loss: 0.0048 - val_mae: 0.0490 - lr: 1.2500e-04
# Epoch 71/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0047 - mae: 0.0495 - val_loss: 0.0048 - val_mae: 0.0499 - lr: 1.2500e-04
# Epoch 72/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0047 - mae: 0.0495 - val_loss: 0.0047 - val_mae: 0.0487 - lr: 1.2500e-04
# Epoch 73/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0047 - mae: 0.0492 - val_loss: 0.0047 - val_mae: 0.0487 - lr: 1.2500e-04
# Epoch 74/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0047 - mae: 0.0492 - val_loss: 0.0047 - val_mae: 0.0485 - lr: 1.2500e-04
# Epoch 75/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0047 - mae: 0.0494 - val_loss: 0.0047 - val_mae: 0.0484 - lr: 1.2500e-04
# Epoch 76/300
# 42/42 [==============================] - 9s 210ms/step - loss: 0.0046 - mae: 0.0489 - val_loss: 0.0047 - val_mae: 0.0483 - lr: 1.2500e-04
# Epoch 77/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0046 - mae: 0.0488 - val_loss: 0.0046 - val_mae: 0.0482 - lr: 1.2500e-04
# Epoch 78/300
# 42/42 [==============================] - 9s 210ms/step - loss: 0.0046 - mae: 0.0489 - val_loss: 0.0047 - val_mae: 0.0482 - lr: 1.2500e-04
# Epoch 79/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0046 - mae: 0.0485 - val_loss: 0.0047 - val_mae: 0.0483 - lr: 1.2500e-04
# Epoch 80/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0046 - mae: 0.0489 - val_loss: 0.0047 - val_mae: 0.0488 - lr: 1.2500e-04
# Epoch 81/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0046 - mae: 0.0489 - val_loss: 0.0048 - val_mae: 0.0501 - lr: 1.2500e-04
# Epoch 82/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0485 - val_loss: 0.0047 - val_mae: 0.0485 - lr: 1.2500e-04
# Epoch 83/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0045 - mae: 0.0481 - val_loss: 0.0046 - val_mae: 0.0486 - lr: 6.2500e-05
# Epoch 84/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0046 - mae: 0.0484 - val_loss: 0.0048 - val_mae: 0.0502 - lr: 6.2500e-05
# Epoch 85/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0046 - mae: 0.0484 - val_loss: 0.0046 - val_mae: 0.0483 - lr: 6.2500e-05
# Epoch 86/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0046 - mae: 0.0484 - val_loss: 0.0046 - val_mae: 0.0481 - lr: 6.2500e-05
# Epoch 87/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0482 - val_loss: 0.0045 - val_mae: 0.0478 - lr: 6.2500e-05
# Epoch 88/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0481 - val_loss: 0.0046 - val_mae: 0.0481 - lr: 3.1250e-05
# Epoch 89/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0481 - val_loss: 0.0046 - val_mae: 0.0482 - lr: 3.1250e-05
# Epoch 90/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0477 - val_loss: 0.0046 - val_mae: 0.0481 - lr: 3.1250e-05
# Epoch 91/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0481 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 3.1250e-05
# Epoch 92/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0045 - mae: 0.0480 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 3.1250e-05
# Epoch 93/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0045 - mae: 0.0479 - val_loss: 0.0045 - val_mae: 0.0477 - lr: 3.1250e-05
# Epoch 94/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0480 - val_loss: 0.0045 - val_mae: 0.0478 - lr: 3.1250e-05
# Epoch 95/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0045 - mae: 0.0479 - val_loss: 0.0046 - val_mae: 0.0479 - lr: 3.1250e-05
# Epoch 96/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0478 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 3.1250e-05
# Epoch 97/300
# 42/42 [==============================] - 9s 207ms/step - loss: 0.0045 - mae: 0.0478 - val_loss: 0.0046 - val_mae: 0.0478 - lr: 3.1250e-05
# Epoch 98/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0479 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.5625e-05
# Epoch 99/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0478 - val_loss: 0.0045 - val_mae: 0.0477 - lr: 1.5625e-05
# Epoch 100/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0045 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.5625e-05
# Epoch 101/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0045 - mae: 0.0479 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.5625e-05
# Epoch 102/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0045 - mae: 0.0479 - val_loss: 0.0045 - val_mae: 0.0477 - lr: 1.5625e-05
# Epoch 103/300
# 42/42 [==============================] - 9s 210ms/step - loss: 0.0044 - mae: 0.0478 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 104/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 105/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 106/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 107/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0045 - mae: 0.0482 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 108/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 109/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0477 - lr: 1.0000e-05
# Epoch 110/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0044 - mae: 0.0478 - val_loss: 0.0045 - val_mae: 0.0478 - lr: 1.0000e-05
# Epoch 111/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0477 - lr: 1.0000e-05
# Epoch 112/300
# 42/42 [==============================] - 9s 209ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0479 - lr: 1.0000e-05
# Epoch 113/300
# 42/42 [==============================] - 9s 208ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0478 - lr: 1.0000e-05
# Epoch 114/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0045 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 115/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 116/300
# 42/42 [==============================] - 9s 205ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 117/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 118/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 119/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 120/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0477 - lr: 1.0000e-05
# Epoch 121/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 122/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 123/300
# 42/42 [==============================] - 9s 205ms/step - loss: 0.0045 - mae: 0.0480 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 124/300
# 42/42 [==============================] - 9s 205ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 125/300
# 42/42 [==============================] - 9s 205ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 126/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 127/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 128/300
# 42/42 [==============================] - 9s 205ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 129/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 130/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 131/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 132/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 133/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 134/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0477 - lr: 1.0000e-05
# Epoch 135/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 136/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 137/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0045 - mae: 0.0479 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 138/300
# 42/42 [==============================] - 8s 203ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 139/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 140/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 141/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 142/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 143/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 144/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 145/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 146/300
# 42/42 [==============================] - 9s 206ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 147/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 148/300
# 42/42 [==============================] - 9s 205ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 149/300
# 42/42 [==============================] - 9s 205ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 150/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0045 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 151/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 152/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 153/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 154/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0475 - lr: 1.0000e-05
# Epoch 155/300
# 42/42 [==============================] - 9s 205ms/step - loss: 0.0044 - mae: 0.0478 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 156/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 157/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0476 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 158/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 159/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0043 - mae: 0.0471 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 160/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 161/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 162/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0043 - mae: 0.0471 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 163/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 164/300
# 42/42 [==============================] - 9s 203ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 165/300
# 42/42 [==============================] - 9s 204ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 166/300
# 42/42 [==============================] - 8s 202ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 167/300
# 42/42 [==============================] - 8s 200ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0045 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 168/300
# 42/42 [==============================] - 8s 200ms/step - loss: 0.0044 - mae: 0.0477 - val_loss: 0.0045 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 169/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 170/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0044 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 171/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0045 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 172/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0045 - val_mae: 0.0476 - lr: 1.0000e-05
# Epoch 173/300
# 42/42 [==============================] - 8s 200ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 174/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 175/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 176/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0470 - lr: 1.0000e-05
# Epoch 177/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0471 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 178/300
# 42/42 [==============================] - 8s 200ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 179/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 180/300
# 42/42 [==============================] - 8s 195ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0470 - lr: 1.0000e-05
# Epoch 181/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 182/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 183/300
# 42/42 [==============================] - 8s 195ms/step - loss: 0.0043 - mae: 0.0471 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 184/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 185/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 186/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0044 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0473 - lr: 1.0000e-05
# Epoch 187/300
# 42/42 [==============================] - 8s 195ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 188/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0045 - val_mae: 0.0474 - lr: 1.0000e-05
# Epoch 189/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 190/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 191/300
# 42/42 [==============================] - 8s 195ms/step - loss: 0.0043 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 192/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 193/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0470 - lr: 1.0000e-05
# Epoch 194/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0471 - val_loss: 0.0044 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 195/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 196/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 197/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 198/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 199/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 200/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 201/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 202/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 203/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 204/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0470 - lr: 1.0000e-05
# Epoch 205/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 206/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 207/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 208/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 209/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 210/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0471 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 211/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0044 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 212/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 213/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 214/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0471 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 215/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0471 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 216/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 217/300
# 42/42 [==============================] - 8s 191ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 218/300
# 42/42 [==============================] - 8s 202ms/step - loss: 0.0043 - mae: 0.0471 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 219/300
# 42/42 [==============================] - 8s 202ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 220/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 221/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 222/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 223/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 224/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 225/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 226/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 227/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 228/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0470 - lr: 1.0000e-05
# Epoch 229/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 230/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0472 - lr: 1.0000e-05
# Epoch 231/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 232/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 233/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 234/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 235/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 236/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 237/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 238/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0470 - lr: 1.0000e-05
# Epoch 239/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 240/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 241/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 242/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 243/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 244/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 245/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0044 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 246/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0465 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 247/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0470 - lr: 1.0000e-05
# Epoch 248/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 249/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0043 - val_mae: 0.0464 - lr: 1.0000e-05
# Epoch 250/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 251/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 252/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0471 - lr: 1.0000e-05
# Epoch 253/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 254/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 255/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 256/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 257/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0464 - lr: 1.0000e-05
# Epoch 258/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 259/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0465 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 260/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0463 - lr: 1.0000e-05
# Epoch 261/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 262/300
# 42/42 [==============================] - 8s 200ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0044 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 263/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 264/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0465 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 265/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 266/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 267/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0470 - val_loss: 0.0043 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 268/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 269/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 270/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0043 - val_mae: 0.0464 - lr: 1.0000e-05
# Epoch 271/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0043 - val_mae: 0.0463 - lr: 1.0000e-05
# Epoch 272/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 273/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 274/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0044 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 275/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 276/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 277/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0463 - lr: 1.0000e-05
# Epoch 278/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0043 - val_mae: 0.0463 - lr: 1.0000e-05
# Epoch 279/300
# 42/42 [==============================] - 8s 195ms/step - loss: 0.0042 - mae: 0.0463 - val_loss: 0.0043 - val_mae: 0.0466 - lr: 1.0000e-05
# Epoch 280/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0043 - mae: 0.0465 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 281/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0043 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 282/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 283/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0468 - val_loss: 0.0043 - val_mae: 0.0462 - lr: 1.0000e-05
# Epoch 284/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0043 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 285/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0468 - lr: 1.0000e-05
# Epoch 286/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0464 - lr: 1.0000e-05
# Epoch 287/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 288/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0043 - val_mae: 0.0462 - lr: 1.0000e-05
# Epoch 289/300
# 42/42 [==============================] - 8s 199ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0464 - lr: 1.0000e-05
# Epoch 290/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 291/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0043 - val_mae: 0.0464 - lr: 1.0000e-05
# Epoch 292/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 293/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0042 - mae: 0.0465 - val_loss: 0.0043 - val_mae: 0.0465 - lr: 1.0000e-05
# Epoch 294/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0042 - mae: 0.0463 - val_loss: 0.0043 - val_mae: 0.0462 - lr: 1.0000e-05
# Epoch 295/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0463 - lr: 1.0000e-05
# Epoch 296/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0043 - mae: 0.0465 - val_loss: 0.0043 - val_mae: 0.0464 - lr: 1.0000e-05
# Epoch 297/300
# 42/42 [==============================] - 8s 196ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0043 - val_mae: 0.0467 - lr: 1.0000e-05
# Epoch 298/300
# 42/42 [==============================] - 8s 197ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0043 - val_mae: 0.0463 - lr: 1.0000e-05
# Epoch 299/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0463 - val_loss: 0.0043 - val_mae: 0.0469 - lr: 1.0000e-05
# Epoch 300/300
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0043 - val_mae: 0.0463 - lr: 1.0000e-05

# %%
# plots of the training (accuracy on training and validation test)

best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('SubmissionModel')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb186204a50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb1850ba190> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb1805c7210> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb18876e050> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
model = tfk.models.load_model('SubmissionModel')

# %% [markdown]
# Visualize our predictions on the test set

# %%
reg_telescope = 864 #1st phase length
X_test_reg, y_test_reg = build_sequences(X_test_raw, target_labels, window, stride, reg_telescope)
X_test_reg.shape, y_test_reg.shape
# Out:
# ((274, 315, 7), (274, 864, 7))

# %%
# Autoregressive Forecasting --> forecasting in a for loop
reg_predictions = np.array([])
X_temp = X_test_reg
for reg in range(0,reg_telescope,telescope):
    pred_temp = model.predict(np.delete(X_temp,[1,2],2))
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)

# %%
reg_predictions.shape
# Out:
# (274, 864, 7)

# %%
mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.012063001>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.08193149>)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, np.delete(target_labels,[1,2]),reg_telescope)
