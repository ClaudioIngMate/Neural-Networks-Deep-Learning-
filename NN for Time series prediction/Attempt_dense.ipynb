# %% [markdown]
# Settings

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/CONSEGNA/5.13-retediversa
# Out:
# /gdrive/My Drive/CONSEGNA/5.13-retediversa

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# Data Loading in a *dataframe*

# %%
dataset = pd.read_csv('Training.csv')
print(dataset.shape)
dataset.head()
# Out:
# (68528, 7)
#    Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# 0     7.97698       4.33494  ...          51.681460    3.65434
# 1     8.07824       4.44616  ...          51.563598    3.47672
# 2     8.02844       4.22372  ...          50.863080    3.47672
# 3     8.02844       4.22372  ...          45.841581    3.47672
# 4     7.87572       4.44616  ...          47.126421    3.47672
#
# [5 rows x 7 columns]

# %%
#the correlation 
dataset.corr()
#Crunchiness and Hype root are 99% correlated!
#Wonder level and Loudness on impact are 93% correlated!
# Out:
#                     Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# Sponginess            1.000000      0.253002  ...           0.127885   0.183141
# Wonder level          0.253002      1.000000  ...           0.237021   0.074392
# Crunchiness           0.297509      0.119078  ...           0.061539   0.987209
# Loudness on impact    0.121744      0.930254  ...           0.229336   0.048806
# Meme creativity       0.331200      0.367438  ...           0.078168  -0.040596
# Soap slipperiness     0.127885      0.237021  ...           1.000000   0.050996
# Hype root             0.183141      0.074392  ...           0.050996   1.000000
#
# [7 rows x 7 columns]

# %% [markdown]
# *Training - Test* (0.90/0.1) **split** + **Normalization** (MinMax scaler)

# %%
#Split
dataset_len = len(dataset)
print(dataset_len)
split=0.1
test_size=int(dataset_len*split) # validation set size
print(test_size)
X_train_raw = dataset.iloc[:-test_size]
X_test_raw = dataset.iloc[-test_size:]
print(X_train_raw.shape, X_test_raw.shape)

#Maximum and minimum
X_min = X_train_raw.min()
X_max = X_train_raw.max()

#MinMax scaler
X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_test_raw = (X_test_raw-X_min)/(X_max-X_min)

# Plot of Training and Validation split with normalized data
plt.figure(figsize=(17,5))
plt.plot(X_train_raw.Crunchiness, label='Train (Crunchiness)')
plt.plot(X_test_raw.Crunchiness, label='Test (Crunchiness)')
plt.title('Train-Test Split')
plt.legend()
plt.show()
# Out:
# 68528
# 5482
# (63046, 7) (5482, 7)
# X_max =  Sponginess            15.106680
# Wonder level          18.122899
# Crunchiness           41.138801
# Loudness on impact    14.035980
# Meme creativity        6.056360
# Soap slipperiness     77.371620
# Hype root             31.024420
# dtype: float64
# X_min =  Sponginess            -0.972080
# Wonder level          -8.450380
# Crunchiness          -34.802881
# Loudness on impact    -9.028060
# Meme creativity       -1.275860
# Soap slipperiness     -6.006860
# Hype root            -38.816760
# dtype: float64

# %% [markdown]
# Parameters for Time Series forecasting with an AutoRegressive model

# %%
window = 315 
stride = 21  
target_labels = dataset.columns    
telescope = 9

# %% [markdown]
# Build the sequences (using previous parameters), necessary for training the network

# %%
def build_sequences(df, target_labels=['pollution'], window=window, stride=stride, telescope=telescope):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
X_test, y_test = build_sequences(X_test_raw, target_labels, window, stride, telescope)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((3000, 315, 7), (3000, 9, 7), (255, 315, 7), (255, 9, 7))

# %%
future = dataset[-window:] # FUTURE is the last window of the dataset
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 315, 7)

# %%
# Correlation: remove crunchiness and wonder level from training set, redundant
X_train = np.delete(X_train,[1,2],2) 
print(X_train.shape,y_train.shape)
# Out:
# (3000, 315, 5) (3000, 9, 7)

# %%
# Model metadata
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 64
epochs = 300

# %%
# model (inspired by one done in Lab classes)

def build_LSTM_model(input_shape, output_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    convlstm = tfkl.Bidirectional(tfkl.LSTM(128, return_sequences=True))(input_layer)
    convlstm = tfkl.MaxPool1D()(convlstm)

    convlstm = tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True))(convlstm)
    convlstm = tfkl.GlobalAveragePooling1D()(convlstm)

    convlstm = tfkl.Dropout(.3)(convlstm)
    convlstm = tfkl.Dense(128)(convlstm)
    convlstm = tfkl.Dense(256)(convlstm)
    convlstm = tfkl.Dense(128)(convlstm)
    convlstm = tfkl.Dense(256)(convlstm)
 
    convlstm = tfkl.Dropout(.3)(convlstm)

    

    dense = tfkl.Dense(output_shape[-1]*output_shape[-2], activation='sigmoid')(convlstm)
    output_layer = tfkl.Reshape((output_shape[-2],output_shape[-1]))(dense)
    

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae']) 

    # Return the model
    return model

# %%
model = build_LSTM_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 315, 5)]          0
#
#  bidirectional (Bidirectiona  (None, 315, 256)         137216
#  l)
#
#  max_pooling1d (MaxPooling1D  (None, 157, 256)         0
#  )
#
#  bidirectional_1 (Bidirectio  (None, 157, 512)         1050624
#  nal)
#
#  global_average_pooling1d (G  (None, 512)              0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 256)               33024
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 63)                16191
#
#  reshape (Reshape)           (None, 9, 7)              0
#
# =================================================================
# Total params: 1,368,639
# Trainable params: 1,368,639
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=25, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/300
# 43/43 [==============================] - 10s 113ms/step - loss: 0.0173 - mae: 0.0992 - val_loss: 0.0175 - val_mae: 0.0925 - lr: 0.0010
# Epoch 2/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0125 - mae: 0.0821 - val_loss: 0.0182 - val_mae: 0.0888 - lr: 0.0010
# Epoch 3/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0114 - mae: 0.0781 - val_loss: 0.0178 - val_mae: 0.0852 - lr: 0.0010
# Epoch 4/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0110 - mae: 0.0760 - val_loss: 0.0170 - val_mae: 0.0916 - lr: 0.0010
# Epoch 5/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0109 - mae: 0.0757 - val_loss: 0.0181 - val_mae: 0.0865 - lr: 0.0010
# Epoch 6/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0106 - mae: 0.0749 - val_loss: 0.0185 - val_mae: 0.0967 - lr: 0.0010
# Epoch 7/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0100 - mae: 0.0733 - val_loss: 0.0159 - val_mae: 0.0851 - lr: 0.0010
# Epoch 8/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0095 - mae: 0.0720 - val_loss: 0.0167 - val_mae: 0.0890 - lr: 0.0010
# Epoch 9/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0094 - mae: 0.0713 - val_loss: 0.0123 - val_mae: 0.0799 - lr: 0.0010
# Epoch 10/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0084 - mae: 0.0683 - val_loss: 0.0142 - val_mae: 0.0782 - lr: 0.0010
# Epoch 11/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0085 - mae: 0.0682 - val_loss: 0.0126 - val_mae: 0.0775 - lr: 0.0010
# Epoch 12/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0081 - mae: 0.0666 - val_loss: 0.0118 - val_mae: 0.0773 - lr: 0.0010
# Epoch 13/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0077 - mae: 0.0653 - val_loss: 0.0114 - val_mae: 0.0780 - lr: 0.0010
# Epoch 14/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0076 - mae: 0.0645 - val_loss: 0.0118 - val_mae: 0.0764 - lr: 0.0010
# Epoch 15/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0075 - mae: 0.0641 - val_loss: 0.0115 - val_mae: 0.0772 - lr: 0.0010
# Epoch 16/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0077 - mae: 0.0652 - val_loss: 0.0108 - val_mae: 0.0761 - lr: 0.0010
# Epoch 17/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0074 - mae: 0.0638 - val_loss: 0.0096 - val_mae: 0.0675 - lr: 0.0010
# Epoch 18/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0065 - mae: 0.0603 - val_loss: 0.0105 - val_mae: 0.0788 - lr: 0.0010
# Epoch 19/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0064 - mae: 0.0600 - val_loss: 0.0091 - val_mae: 0.0676 - lr: 0.0010
# Epoch 20/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0059 - mae: 0.0577 - val_loss: 0.0081 - val_mae: 0.0670 - lr: 0.0010
# Epoch 21/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0056 - mae: 0.0565 - val_loss: 0.0066 - val_mae: 0.0600 - lr: 0.0010
# Epoch 22/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0050 - mae: 0.0536 - val_loss: 0.0071 - val_mae: 0.0634 - lr: 0.0010
# Epoch 23/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0051 - mae: 0.0539 - val_loss: 0.0063 - val_mae: 0.0583 - lr: 0.0010
# Epoch 24/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0049 - mae: 0.0529 - val_loss: 0.0071 - val_mae: 0.0621 - lr: 0.0010
# Epoch 25/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0047 - mae: 0.0518 - val_loss: 0.0067 - val_mae: 0.0589 - lr: 0.0010
# Epoch 26/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0047 - mae: 0.0516 - val_loss: 0.0055 - val_mae: 0.0528 - lr: 0.0010
# Epoch 27/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0045 - mae: 0.0507 - val_loss: 0.0055 - val_mae: 0.0535 - lr: 0.0010
# Epoch 28/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0043 - mae: 0.0493 - val_loss: 0.0052 - val_mae: 0.0534 - lr: 0.0010
# Epoch 29/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0043 - mae: 0.0498 - val_loss: 0.0056 - val_mae: 0.0559 - lr: 0.0010
# Epoch 30/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0039 - mae: 0.0472 - val_loss: 0.0059 - val_mae: 0.0577 - lr: 0.0010
# Epoch 31/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0042 - mae: 0.0493 - val_loss: 0.0053 - val_mae: 0.0538 - lr: 0.0010
# Epoch 32/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0039 - mae: 0.0472 - val_loss: 0.0049 - val_mae: 0.0491 - lr: 0.0010
# Epoch 33/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0035 - mae: 0.0443 - val_loss: 0.0060 - val_mae: 0.0568 - lr: 0.0010
# Epoch 34/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0036 - mae: 0.0444 - val_loss: 0.0047 - val_mae: 0.0489 - lr: 0.0010
# Epoch 35/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0036 - mae: 0.0448 - val_loss: 0.0050 - val_mae: 0.0505 - lr: 0.0010
# Epoch 36/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0035 - mae: 0.0441 - val_loss: 0.0051 - val_mae: 0.0502 - lr: 0.0010
# Epoch 37/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0047 - val_mae: 0.0495 - lr: 0.0010
# Epoch 38/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0034 - mae: 0.0433 - val_loss: 0.0045 - val_mae: 0.0477 - lr: 0.0010
# Epoch 39/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0032 - mae: 0.0421 - val_loss: 0.0043 - val_mae: 0.0468 - lr: 0.0010
# Epoch 40/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0033 - mae: 0.0430 - val_loss: 0.0051 - val_mae: 0.0493 - lr: 0.0010
# Epoch 41/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0033 - mae: 0.0425 - val_loss: 0.0041 - val_mae: 0.0453 - lr: 0.0010
# Epoch 42/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0049 - val_mae: 0.0523 - lr: 0.0010
# Epoch 43/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0031 - mae: 0.0410 - val_loss: 0.0042 - val_mae: 0.0472 - lr: 0.0010
# Epoch 44/300
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0030 - mae: 0.0408 - val_loss: 0.0040 - val_mae: 0.0446 - lr: 0.0010
# Epoch 45/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0030 - mae: 0.0405 - val_loss: 0.0045 - val_mae: 0.0493 - lr: 0.0010
# Epoch 46/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0031 - mae: 0.0411 - val_loss: 0.0045 - val_mae: 0.0487 - lr: 0.0010
# Epoch 47/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0031 - mae: 0.0409 - val_loss: 0.0041 - val_mae: 0.0448 - lr: 0.0010
# Epoch 48/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0030 - mae: 0.0407 - val_loss: 0.0040 - val_mae: 0.0458 - lr: 0.0010
# Epoch 49/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0029 - mae: 0.0398 - val_loss: 0.0039 - val_mae: 0.0436 - lr: 0.0010
# Epoch 50/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0028 - mae: 0.0388 - val_loss: 0.0037 - val_mae: 0.0426 - lr: 0.0010
# Epoch 51/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0029 - mae: 0.0401 - val_loss: 0.0045 - val_mae: 0.0485 - lr: 0.0010
# Epoch 52/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0028 - mae: 0.0390 - val_loss: 0.0036 - val_mae: 0.0411 - lr: 0.0010
# Epoch 53/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0028 - mae: 0.0395 - val_loss: 0.0051 - val_mae: 0.0511 - lr: 0.0010
# Epoch 54/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0029 - mae: 0.0401 - val_loss: 0.0039 - val_mae: 0.0429 - lr: 0.0010
# Epoch 55/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0028 - mae: 0.0390 - val_loss: 0.0037 - val_mae: 0.0416 - lr: 0.0010
# Epoch 56/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0027 - mae: 0.0385 - val_loss: 0.0041 - val_mae: 0.0450 - lr: 0.0010
# Epoch 57/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0028 - mae: 0.0397 - val_loss: 0.0049 - val_mae: 0.0475 - lr: 0.0010
# Epoch 58/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0025 - mae: 0.0366 - val_loss: 0.0035 - val_mae: 0.0392 - lr: 5.0000e-04
# Epoch 59/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0025 - mae: 0.0363 - val_loss: 0.0035 - val_mae: 0.0399 - lr: 5.0000e-04
# Epoch 60/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0024 - mae: 0.0355 - val_loss: 0.0034 - val_mae: 0.0389 - lr: 5.0000e-04
# Epoch 61/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0024 - mae: 0.0355 - val_loss: 0.0034 - val_mae: 0.0393 - lr: 5.0000e-04
# Epoch 62/300
# 43/43 [==============================] - 3s 71ms/step - loss: 0.0024 - mae: 0.0355 - val_loss: 0.0035 - val_mae: 0.0396 - lr: 5.0000e-04
# Epoch 63/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0023 - mae: 0.0351 - val_loss: 0.0034 - val_mae: 0.0389 - lr: 5.0000e-04
# Epoch 64/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0025 - mae: 0.0363 - val_loss: 0.0034 - val_mae: 0.0396 - lr: 5.0000e-04
# Epoch 65/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0024 - mae: 0.0357 - val_loss: 0.0035 - val_mae: 0.0395 - lr: 5.0000e-04
# Epoch 66/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0022 - mae: 0.0345 - val_loss: 0.0033 - val_mae: 0.0383 - lr: 2.5000e-04
# Epoch 67/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0022 - mae: 0.0341 - val_loss: 0.0032 - val_mae: 0.0372 - lr: 2.5000e-04
# Epoch 68/300
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0022 - mae: 0.0339 - val_loss: 0.0032 - val_mae: 0.0377 - lr: 2.5000e-04
# Epoch 69/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0022 - mae: 0.0339 - val_loss: 0.0033 - val_mae: 0.0379 - lr: 2.5000e-04
# Epoch 70/300
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0022 - mae: 0.0337 - val_loss: 0.0033 - val_mae: 0.0381 - lr: 2.5000e-04
# Epoch 71/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0021 - mae: 0.0336 - val_loss: 0.0033 - val_mae: 0.0385 - lr: 2.5000e-04
# Epoch 72/300
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0021 - mae: 0.0333 - val_loss: 0.0032 - val_mae: 0.0374 - lr: 1.2500e-04
# Epoch 73/300
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0021 - mae: 0.0331 - val_loss: 0.0032 - val_mae: 0.0373 - lr: 1.2500e-04
# Epoch 74/300
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0021 - mae: 0.0332 - val_loss: 0.0032 - val_mae: 0.0373 - lr: 1.2500e-04
# Epoch 75/300
# 43/43 [==============================] - 3s 74ms/step - loss: 0.0021 - mae: 0.0329 - val_loss: 0.0032 - val_mae: 0.0377 - lr: 1.2500e-04
# Epoch 76/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0021 - mae: 0.0334 - val_loss: 0.0032 - val_mae: 0.0374 - lr: 1.2500e-04
# Epoch 77/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0021 - mae: 0.0329 - val_loss: 0.0032 - val_mae: 0.0373 - lr: 1.2500e-04
# Epoch 78/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0021 - mae: 0.0332 - val_loss: 0.0032 - val_mae: 0.0374 - lr: 1.2500e-04
# Epoch 79/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0326 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 6.2500e-05
# Epoch 80/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0325 - val_loss: 0.0032 - val_mae: 0.0373 - lr: 6.2500e-05
# Epoch 81/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0328 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 6.2500e-05
# Epoch 82/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0326 - val_loss: 0.0032 - val_mae: 0.0377 - lr: 6.2500e-05
# Epoch 83/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0326 - val_loss: 0.0032 - val_mae: 0.0371 - lr: 6.2500e-05
# Epoch 84/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0323 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 3.1250e-05
# Epoch 85/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0323 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 3.1250e-05
# Epoch 86/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0324 - val_loss: 0.0031 - val_mae: 0.0372 - lr: 3.1250e-05
# Epoch 87/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0324 - val_loss: 0.0031 - val_mae: 0.0373 - lr: 3.1250e-05
# Epoch 88/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0325 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 3.1250e-05
# Epoch 89/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.5625e-05
# Epoch 90/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0320 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.5625e-05
# Epoch 91/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0323 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 1.5625e-05
# Epoch 92/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 1.5625e-05
# Epoch 93/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.5625e-05
# Epoch 94/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0321 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.0000e-05
# Epoch 95/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0323 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 1.0000e-05
# Epoch 96/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 1.0000e-05
# Epoch 97/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0323 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.0000e-05
# Epoch 98/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0323 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 1.0000e-05
# Epoch 99/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0324 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.0000e-05
# Epoch 100/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0321 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 1.0000e-05
# Epoch 101/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 1.0000e-05
# Epoch 102/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0321 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 1.0000e-05
# Epoch 103/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.0000e-05
# Epoch 104/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0321 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 1.0000e-05
# Epoch 105/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.0000e-05
# Epoch 106/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0321 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.0000e-05
# Epoch 107/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0320 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.0000e-05
# Epoch 108/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0320 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 1.0000e-05
# Epoch 109/300
# 43/43 [==============================] - 3s 72ms/step - loss: 0.0020 - mae: 0.0321 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 1.0000e-05
# Epoch 110/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0320 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 1.0000e-05
# Epoch 111/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0371 - lr: 1.0000e-05
# Epoch 112/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0321 - val_loss: 0.0031 - val_mae: 0.0369 - lr: 1.0000e-05
# Epoch 113/300
# 43/43 [==============================] - 3s 73ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0031 - val_mae: 0.0370 - lr: 1.0000e-05

# %%
# plots of the training (accuracy on training and validation test)

best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('SubmissionModel1')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as lstm_cell_43_layer_call_fn, lstm_cell_43_layer_call_and_return_conditional_losses, lstm_cell_44_layer_call_fn, lstm_cell_44_layer_call_and_return_conditional_losses, lstm_cell_46_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb6bdb5e5d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb6f8bc9390> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb709005790> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb70619fad0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
model = tfk.models.load_model('SubmissionModel')

# %% [markdown]
# Visualize our predictions on the test set

# %%
reg_telescope = 864 #1st phase length
X_test_reg, y_test_reg = build_sequences(X_test_raw, target_labels, window, stride, reg_telescope)
X_test_reg.shape, y_test_reg.shape
# Out:
# ((214, 315, 7), (214, 864, 7))

# %%
# Autoregressive Forecasting --> forecasting in a for loop
reg_predictions = np.array([])
X_temp = X_test_reg
for reg in range(0,reg_telescope,telescope):
    pred_temp = model.predict(np.delete(X_temp,[1,2],2))
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)

# %%
reg_predictions.shape
# Out:
# (214, 864, 7)

# %%
mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.012732545>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.08442599>)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
np.delete(target_labels,[1,2])
# Out:
# Index(['Sponginess', 'Loudness on impact', 'Meme creativity',
#        'Soap slipperiness', 'Hype root'],
#       dtype='object')

# %%
inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, np.delete(target_labels,[1,2]), reg_telescope)
